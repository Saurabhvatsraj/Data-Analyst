# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv')
df
# Out:
#          Creditor         Debtor  Amount         Risk
# 0           Japan  United States  796.00       Stable
# 1          France          Italy  366.00    High Risk
# 2         Britain  United States  345.00       Stable
# 3           Spain        Britain  326.00       Stable
# 4         Germany  United States  324.00       Stable
# 5          France  United States  322.00       Stable
# 6         Germany        Britain  321.00       Stable
# 7           Spain  United States  163.00       Stable
# 8          France          Spain  118.00  Medium Risk
# 9           Italy        Germany  111.00       Stable
# 10          Japan        Germany   88.50       Stable
# 11          Spain       Portugal   62.00    High Risk
# 12        Germany          Spain   57.60  Medium Risk
# 13         France         Greece   53.90    High Risk
# 14         France        Germany   53.80       Stable
# 15        Germany        Ireland   48.90    High Risk
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\saura\Data_Analyst

# %%
df.columns
# Out:
# Index(['Creditor', 'Debtor', 'Amount', 'Risk'], dtype='object')

# %%
# how many rows we want
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',nrows=1)
df
# Out:
#   Creditor         Debtor  Amount    Risk
# 0    Japan  United States     796  Stable

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',nrows=4)
df
# Out:
#   Creditor         Debtor  Amount       Risk
# 0    Japan  United States     796     Stable
# 1   France          Italy     366  High Risk
# 2  Britain  United States     345     Stable
# 3    Spain        Britain     326     Stable

# %%
# how many column we want--- using column index value
dff=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',usecols=[0])
dff
# Out:
#          Creditor
# 0           Japan
# 1          France
# 2         Britain
# 3           Spain
# 4         Germany
# 5          France
# 6         Germany
# 7           Spain
# 8          France
# 9           Italy
# 10          Japan
# 11          Spain
# 12        Germany
# 13         France
# 14         France
# 15        Germany
# 16          Japan
# 17        Germany
# 18          Japan
# 19        Britain
# 20          Japan
# 21        Britain
# 22        Britain
# 23        Germany
# 24          Japan
# 25         France
# 26         France
# 27        Ireland
# 28  United States
# 29       Portugal
# 30          Spain
# 31         France
# 32        Ireland
# 33       Portugal
# 34          Italy
# 35  United States
# 36  United States
# 37          Italy
# 38          Japan
# 39          Japan
# 40          Italy
# 41          Spain
# 42        Britain
# 43       Portugal
# 44        Ireland

# %%
df1=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',usecols=[2,3])
df1
# Out:
#     Amount         Risk
# 0   796.00       Stable
# 1   366.00    High Risk
# 2   345.00       Stable
# 3   326.00       Stable
# 4   324.00       Stable
# 5   322.00       Stable
# 6   321.00       Stable
# 7   163.00       Stable
# 8   118.00  Medium Risk
# 9   111.00       Stable
# 10   88.50       Stable
# 11   62.00    High Risk
# 12   57.60  Medium Risk
# 13   53.90    High Risk
# 14   53.80       Stable
# 15   48.90    High Risk
# 16   38.80    High Risk
# 17   32.50    High Risk
# 18   28.20       Stable
# 19   26.00    High Risk
# 20   25.90  Medium Risk
# 21   22.40     Low Risk
# 22   19.40    High Risk
# 23   19.30    High Risk
# 24   18.90    High Risk
# 25   18.30    High Risk
# 26   17.30    High Risk
# 27   12.00       Stable
# 28   11.10    High Risk
# 29   10.10    High Risk
# 30    9.79    High Risk
# 31    7.73       Stable
# 32    6.38  Medium Risk
# 33    3.77    High Risk
# 34    3.22    High Risk
# 35    3.16    High Risk
# 36    3.10    High Risk
# ...

# %%
df.head()
# Out:
#   Creditor         Debtor  Amount       Risk
# 0    Japan  United States     796     Stable
# 1   France          Italy     366  High Risk
# 2  Britain  United States     345     Stable
# 3    Spain        Britain     326     Stable

# %%
df2=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',skiprows=1)
df2
# Out:
#             Japan  United States     796       Stable
# 0          France          Italy  366.00    High Risk
# 1         Britain  United States  345.00       Stable
# 2           Spain        Britain  326.00       Stable
# 3         Germany  United States  324.00       Stable
# 4          France  United States  322.00       Stable
# 5         Germany        Britain  321.00       Stable
# 6           Spain  United States  163.00       Stable
# 7          France          Spain  118.00  Medium Risk
# 8           Italy        Germany  111.00       Stable
# 9           Japan        Germany   88.50       Stable
# 10          Spain       Portugal   62.00    High Risk
# 11        Germany          Spain   57.60  Medium Risk
# 12         France         Greece   53.90    High Risk
# 13         France        Germany   53.80       Stable
# 14        Germany        Ireland   48.90    High Risk
# 15          Japan          Italy   38.80    High Risk
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',skiprows=4)
df
# Out:
#             Spain        Britain     326       Stable
# 0         Germany  United States  324.00       Stable
# 1          France  United States  322.00       Stable
# 2         Germany        Britain  321.00       Stable
# 3           Spain  United States  163.00       Stable
# 4          France          Spain  118.00  Medium Risk
# 5           Italy        Germany  111.00       Stable
# 6           Japan        Germany   88.50       Stable
# 7           Spain       Portugal   62.00    High Risk
# 8         Germany          Spain   57.60  Medium Risk
# 9          France         Greece   53.90    High Risk
# 10         France        Germany   53.80       Stable
# 11        Germany        Ireland   48.90    High Risk
# 12          Japan          Italy   38.80    High Risk
# 13        Germany       Portugal   32.50    High Risk
# 14          Japan        Britain   28.20       Stable
# 15        Britain          Italy   26.00    High Risk
# ...

# %%
# giving index value and hiding the rows
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',skiprows=[6])
df
# Out:
#          Creditor         Debtor  Amount         Risk
# 0           Japan  United States  796.00       Stable
# 1          France          Italy  366.00    High Risk
# 2         Britain  United States  345.00       Stable
# 3           Spain        Britain  326.00       Stable
# 4         Germany  United States  324.00       Stable
# 5         Germany        Britain  321.00       Stable
# 6           Spain  United States  163.00       Stable
# 7          France          Spain  118.00  Medium Risk
# 8           Italy        Germany  111.00       Stable
# 9           Japan        Germany   88.50       Stable
# 10          Spain       Portugal   62.00    High Risk
# 11        Germany          Spain   57.60  Medium Risk
# 12         France         Greece   53.90    High Risk
# 13         France        Germany   53.80       Stable
# 14        Germany        Ireland   48.90    High Risk
# 15          Japan          Italy   38.80    High Risk
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',index_col='Amount')
df
# Out:
#              Creditor         Debtor         Risk
# Amount
# 796.00          Japan  United States       Stable
# 366.00         France          Italy    High Risk
# 345.00        Britain  United States       Stable
# 326.00          Spain        Britain       Stable
# 324.00        Germany  United States       Stable
# 322.00         France  United States       Stable
# 321.00        Germany        Britain       Stable
# 163.00          Spain  United States       Stable
# 118.00         France          Spain  Medium Risk
# 111.00          Italy        Germany       Stable
# 88.50           Japan        Germany       Stable
# 62.00           Spain       Portugal    High Risk
# 57.60         Germany          Spain  Medium Risk
# 53.90          France         Greece    High Risk
# 53.80          France        Germany       Stable
# 48.90         Germany        Ireland    High Risk
# 38.80           Japan          Italy    High Risk
# 32.50         Germany       Portugal    High Risk
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',index_col='Risk')
df
# Out:
#                   Creditor         Debtor  Amount
# Risk
# Stable               Japan  United States  796.00
# High Risk           France          Italy  366.00
# Stable             Britain  United States  345.00
# Stable               Spain        Britain  326.00
# Stable             Germany  United States  324.00
# Stable              France  United States  322.00
# Stable             Germany        Britain  321.00
# Stable               Spain  United States  163.00
# Medium Risk         France          Spain  118.00
# Stable               Italy        Germany  111.00
# Stable               Japan        Germany   88.50
# High Risk            Spain       Portugal   62.00
# Medium Risk        Germany          Spain   57.60
# High Risk           France         Greece   53.90
# Stable              France        Germany   53.80
# High Risk          Germany        Ireland   48.90
# High Risk            Japan          Italy   38.80
# High Risk          Germany       Portugal   32.50
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',header=1)
df
# Out:
#             Japan  United States     796       Stable
# 0          France          Italy  366.00    High Risk
# 1         Britain  United States  345.00       Stable
# 2           Spain        Britain  326.00       Stable
# 3         Germany  United States  324.00       Stable
# 4          France  United States  322.00       Stable
# 5         Germany        Britain  321.00       Stable
# 6           Spain  United States  163.00       Stable
# 7          France          Spain  118.00  Medium Risk
# 8           Italy        Germany  111.00       Stable
# 9           Japan        Germany   88.50       Stable
# 10          Spain       Portugal   62.00    High Risk
# 11        Germany          Spain   57.60  Medium Risk
# 12         France         Greece   53.90    High Risk
# 13         France        Germany   53.80       Stable
# 14        Germany        Ireland   48.90    High Risk
# 15          Japan          Italy   38.80    High Risk
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',header=None)
df
# Out:
#                 0              1       2            3
# 0        Creditor         Debtor  Amount         Risk
# 1           Japan  United States     796       Stable
# 2          France          Italy     366    High Risk
# 3         Britain  United States     345       Stable
# 4           Spain        Britain     326       Stable
# 5         Germany  United States     324       Stable
# 6          France  United States     322       Stable
# 7         Germany        Britain     321       Stable
# 8           Spain  United States     163       Stable
# 9          France          Spain     118  Medium Risk
# 10          Italy        Germany     111       Stable
# 11          Japan        Germany    88.5       Stable
# 12          Spain       Portugal      62    High Risk
# 13        Germany          Spain    57.6  Medium Risk
# 14         France         Greece    53.9    High Risk
# 15         France        Germany    53.8       Stable
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',header=None,prefix='Data')
df
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_17672\1352315355.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',header=None,prefix='Data')
#             Data0          Data1   Data2        Data3
# 0        Creditor         Debtor  Amount         Risk
# 1           Japan  United States     796       Stable
# 2          France          Italy     366    High Risk
# 3         Britain  United States     345       Stable
# 4           Spain        Britain     326       Stable
# 5         Germany  United States     324       Stable
# 6          France  United States     322       Stable
# 7         Germany        Britain     321       Stable
# 8           Spain  United States     163       Stable
# 9          France          Spain     118  Medium Risk
# 10          Italy        Germany     111       Stable
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',names=['A','B','C','D'])
df
# Out:
#                 A              B       C            D
# 0        Creditor         Debtor  Amount         Risk
# 1           Japan  United States     796       Stable
# 2          France          Italy     366    High Risk
# 3         Britain  United States     345       Stable
# 4           Spain        Britain     326       Stable
# 5         Germany  United States     324       Stable
# 6          France  United States     322       Stable
# 7         Germany        Britain     321       Stable
# 8           Spain  United States     163       Stable
# 9          France          Spain     118  Medium Risk
# 10          Italy        Germany     111       Stable
# 11          Japan        Germany    88.5       Stable
# 12          Spain       Portugal      62    High Risk
# 13        Germany          Spain    57.6  Medium Risk
# 14         France         Greece    53.9    High Risk
# 15         France        Germany    53.8       Stable
# ...

# %%
df.head()
# Out:
#           A              B       C          D
# 0  Creditor         Debtor  Amount       Risk
# 1     Japan  United States     796     Stable
# 2    France          Italy     366  High Risk
# 3   Britain  United States     345     Stable
# 4     Spain        Britain     326     Stable

# %%
df.head(1)
# Out:
#           A       B       C     D
# 0  Creditor  Debtor  Amount  Risk

# %%
df.tail()
# Out:
#            A              B     C          D
# 41     Italy       Portugal  0.87  High Risk
# 42     Spain         Greece  0.78  High Risk
# 43   Britain         Greece  0.55  High Risk
# 44  Portugal  United States  0.52     Stable
# 45   Ireland         Greece  0.34  High Risk

# %%
df.tail(1)
# Out:
#           A       B     C          D
# 45  Ireland  Greece  0.34  High Risk

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',dtype={'ID':int})
df
# Out:
#          Creditor         Debtor  Amount         Risk
# 0           Japan  United States  796.00       Stable
# 1          France          Italy  366.00    High Risk
# 2         Britain  United States  345.00       Stable
# 3           Spain        Britain  326.00       Stable
# 4         Germany  United States  324.00       Stable
# 5          France  United States  322.00       Stable
# 6         Germany        Britain  321.00       Stable
# 7           Spain  United States  163.00       Stable
# 8          France          Spain  118.00  Medium Risk
# 9           Italy        Germany  111.00       Stable
# 10          Japan        Germany   88.50       Stable
# 11          Spain       Portugal   62.00    High Risk
# 12        Germany          Spain   57.60  Medium Risk
# 13         France         Greece   53.90    High Risk
# 14         France        Germany   53.80       Stable
# 15        Germany        Ireland   48.90    High Risk
# ...

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',dtype={'ID':int,'Amount':int})
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda\lib\site-packages\pandas\_libs\parsers.pyx:1113, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df=pd.read_csv(r'C:\Users\saura\Downloads\P6-EuroDebtCrisis.csv',dtype={'ID':int,'Amount':int})
#       2 df
#
# File ~\anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
# ...
